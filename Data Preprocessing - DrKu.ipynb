# %% [markdown]
# ## Data Preprocessing - Car Price

# %% [markdown]
# ## Import Packages

# %%
# Import Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
# Import Dataset
raw_data = pd.read_csv('car_price_raw.csv')
raw_data.head(11)
# Out:
#     Price   Age     KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0  46986   Diesel   90.0       1.0          0  2000      3
# 1   13750  23.0  72937   Diesel   90.0       1.0          0  2000      3
# 2   13950  24.0  41711   Diesel   90.0       1.0          0  2000      3
# 3   14950  26.0  48000   Diesel   90.0       0.0          0  2000      3
# 4   13750   NaN  38500   Diesel   90.0       0.0          0  2000      3
# 5   12950  32.0  61000   Diesel   90.0       0.0          0  2000      3
# 6   16900  27.0  94612   Diesel   90.0       1.0          0  2000      3
# 7   18600  30.0  75889   Diesel   90.0       1.0          0  2000      3
# 8   21500  27.0  19700   Petrol  192.0       0.0          0  1800      3
# 9   21500  27.0  19700   Petrol  192.0       0.0          0  1800      3
# 10  12950  23.0  71138   Diesel   69.0       0.0          0  1900      3
#
#     Weight
# 0     1165
# 1     1165
# 2     1165
# 3     1165
# 4     1170
# 5     1170
# 6     1245
# 7     1245
# 8     1185
# 9     1185
# 10    1105

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Overview about the dataset

# %%
# Check total number of attributes
print("No. of Attributes (Columns): ",len(raw_data.columns))
print("No. of sample (Rows): ",len(raw_data))
# Out:
# No. of Attributes (Columns):  10
# No. of sample (Rows):  1437

# %%
raw_data.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1437.000000  1436.000000    1437.000000  1436.000000  1436.000000
# mean   10738.318720    55.944986   68499.276966   101.502089     0.674095
# std     3636.814232    18.603073   37515.511159    14.981080     0.468875
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63328.000000   110.000000     1.000000
# 75%    11950.000000    70.000000   87000.000000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC        Doors       Weight
# count  1437.000000  1437.000000  1437.000000  1437.000000
# mean      0.055672  1566.990257     4.032707  1072.537926
# std       0.229366   187.218323     0.952735    52.706466
# min       0.000000  1300.000000     2.000000  1000.000000
# 25%       0.000000  1400.000000     3.000000  1040.000000
# 50%       0.000000  1600.000000     4.000000  1070.000000
# 75%       0.000000  1600.000000     5.000000  1085.000000
# max       1.000000  2000.000000     5.000000  1615.000000

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 1. YData Profiling (Previously Pandas Profiling)

# %% [markdown]
# ### Interactive and Comprehensive Descriptive Analysis using Pandas-Profiling

# %%
import ydata_profiling as pp
#Interactive and comprehensive EDA/ data description

# forming ProfileReport and save
# as output.html file
profile = pp.ProfileReport(raw_data)
profile.to_file("output_raw_data.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 2. D-Tale

# %% [markdown]
# D-Tale takes your Pandas dataframe to a whole new level. This powerful and fast library makes it very easy to interact with your data, carry out basic analysis and even edit it.

# %%
import dtale

dtale.show(raw_data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://MSI:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# D-Tale comes with a large number of features that allow you to interrogate the data, visualise its completeness, edit the data and more.
#
# When we look into individual variables, such as the DTC column within this dataset, we can visualise the distribution of it using histograms:

# %% [markdown]
# ### 3. SweetViz

# %% [markdown]
# SweetViz is another low code, interactive data visualisation and exploration library. From a couple of lines of code, we are able to create an interactive HTML file to explore our data.

# %%
import sweetviz as sv

report = sv.analyze(raw_data)
report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 4. Missingno

# %% [markdown]
# If you are interested in using a lightweight library to explore the completeness of your data, then missingno is one you should definitely consider for your EDA toolbox.
#
# It is a Python library that provides a series of visualisations to understand the presence and distribution of missing data within a pandas dataframe. The library provides you with a small number of plots (barplot, matrix plot, heatmap or dendrogram) to visualise what columns in your dataframe contain missing values and how the degree of missingness is related between the variables.

# %%
import missingno as msno

msno.bar(raw_data)
msno.matrix(raw_data)
msno.dendrogram(raw_data)
msno.heatmap(raw_data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above four plots provide us insight into:
#
# How complete each column within the dataframe is — msno.bar()
# Where the missing data occurs — msno.matrix()
# How correlated the missing values are — msno.heatmap() and msno.dendrogram()
# The nice thing about this library is that the plots are clean, easy to understand and can be quickly incorporated into a report as they are.

# %% [markdown]
# ### 5. Sketch

# %% [markdown]
# Sketch is a very new (as of Feb 2023) library that leverages the power of AI to help you understand your pandas dataframes by using natural language questions directly within Jupyter. You can also use it to generate sample code, for example how to make a plot of x and y within the dataframe, and then use that code to generate the required plot.
#
# The library is mostly self contained, where it uses machine learning algorithms to understand the context of your question in relation to your dataset. There is a function that does rely on OpenAI’s API, but that does not detract from how the library can be used.
#
# Sketch has a lot of potential to be powerful, especially if you are looking to provide an interface to customers with very limited knowledge of coding in Python.

# %%
# !pip install sketch
# Out:
# Requirement already satisfied: sketch in d:\anaconda\lib\site-packages (0.4.2)
# Requirement already satisfied: pandas>=1.3.0 in d:\anaconda\lib\site-packages (from sketch) (1.5.3)
# Requirement already satisfied: datasketch>=1.5.8 in d:\anaconda\lib\site-packages (from sketch) (1.6.4)
# Requirement already satisfied: datasketches>=4.0.0 in d:\anaconda\lib\site-packages (from sketch) (4.1.0)
# Requirement already satisfied: ipython in d:\anaconda\lib\site-packages (from sketch) (8.15.0)
# Requirement already satisfied: lambdaprompt>=0.5.4 in d:\anaconda\lib\site-packages (from sketch) (0.5.5)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from sketch) (23.1)
# Requirement already satisfied: numpy>=1.11 in d:\anaconda\lib\site-packages (from datasketch>=1.5.8->sketch) (1.23.5)
# Requirement already satisfied: scipy>=1.0.0 in d:\anaconda\lib\site-packages (from datasketch>=1.5.8->sketch) (1.9.3)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (2.28.1)
# Requirement already satisfied: aiohttp in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (3.8.5)
# Requirement already satisfied: python-dotenv in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (0.21.0)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (3.1.2)
# Requirement already satisfied: nest-asyncio in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (1.5.6)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (6.0)
# Requirement already satisfied: tenacity in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (8.2.2)
# Requirement already satisfied: pydantic in d:\anaconda\lib\site-packages (from lambdaprompt>=0.5.4->sketch) (1.10.8)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->sketch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->sketch) (2023.3.post1)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython->sketch) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython->sketch) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython->sketch) (0.18.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from ipython->sketch) (0.1.6)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython->sketch) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\anaconda\lib\site-packages (from ipython->sketch) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from ipython->sketch) (2.15.1)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython->sketch) (0.2.0)
# Requirement already satisfied: traitlets>=5 in d:\anaconda\lib\site-packages (from ipython->sketch) (5.7.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython->sketch) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython->sketch) (0.8.3)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->sketch) (0.2.5)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->sketch) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\lib\site-packages (from aiohttp->lambdaprompt>=0.5.4->sketch) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->lambdaprompt>=0.5.4->sketch) (2.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda\lib\site-packages (from pydantic->lambdaprompt>=0.5.4->sketch) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->lambdaprompt>=0.5.4->sketch) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->lambdaprompt>=0.5.4->sketch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->lambdaprompt>=0.5.4->sketch) (2023.7.22)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython->sketch) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython->sketch) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython->sketch) (0.2.2)

# %%
import sketch

raw_data.sketch.ask('What are the max values of each numerical column?')
# Out:
# Price: 32500.0
# Age: 80.0
# KM: 243000.0
# HP: 192.0
# MetColor: 1.0
# Automatic: 1.0
# CC: 2000.0
# Doors: 5.0
# Weight: 1615.0

# %%
raw_data.sketch.howto("""How do I plot KM against Price 
                using a scatter plot and have the coloured in rainbow?""")
# Out:
# <div style="display:flex;flex-direction:row;justify-content:space-between;">
#                 <pre style="width: 100%; white-space: pre-wrap;" id="5193122d-2f25-4361-9dc4-d5227e5a2bd3">
# import matplotlib.pyplot as plt
#
# # Create a scatter plot of KM vs Price
# plt.scatter(raw_data['KM'], raw_data['Price'], c=raw_data['KM'], cmap='rainbow')
#
# # Add labels and title
# plt.xlabel('Kilometers')
# plt.ylabel('Price')
# plt.title('Kilometers vs Price')
#
# # Show the plot
# plt.show()
# </pre>
#                 <button style="height: fit-content;" onclick="navigator.clipboard.writeText(JSON.parse(atob(``)))">Copy</button>
#                 </div>

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of KM vs Price
plt.scatter(raw_data['KM'], raw_data['Price'], c=raw_data['KM'], cmap='rainbow')

# Add labels and title
plt.xlabel('Kilometers')
plt.ylabel('Price')
plt.title('Kilometers vs Price')

# Show the plot
plt.show()
# Out:
# 2023-11-20 08:56:54,056 - ERROR    - Exception occurred while processing request: 'NoneType' object is not iterable
# Traceback (most recent call last):
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 2867, in get_data
#     curr_dtypes = [c["name"] for c in global_state.get_dtypes(data_id)]
# TypeError: 'NoneType' object is not iterable
# 2023-11-20 08:57:43,005 - ERROR    - Exception occurred while processing request: 'NoneType' object is not iterable
# Traceback (most recent call last):
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 2867, in get_data
#     curr_dtypes = [c["name"] for c in global_state.get_dtypes(data_id)]
# TypeError: 'NoneType' object is not iterable
# 2023-11-20 08:57:48,248 - ERROR    - Exception occurred while processing request: 'NoneType' object is not iterable
# Traceback (most recent call last):
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 2867, in get_data
#     curr_dtypes = [c["name"] for c in global_state.get_dtypes(data_id)]
# TypeError: 'NoneType' object is not iterable
# 2023-11-20 08:58:23,447 - ERROR    - Exception occurred while processing request: 'NoneType' object is not iterable
# Traceback (most recent call last):
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 2867, in get_data
#     curr_dtypes = [c["name"] for c in global_state.get_dtypes(data_id)]
# TypeError: 'NoneType' object is not iterable
# 2023-11-20 09:02:00,023 - ERROR    - Exception occurred while processing request: 'NoneType' object is not iterable
# Traceback (most recent call last):
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 2867, in get_data
#     curr_dtypes = [c["name"] for c in global_state.get_dtypes(data_id)]
# TypeError: 'NoneType' object is not iterable
# 2023-11-20 09:02:43,553 - ERROR    - Exception occurred while processing request: 'NoneType' object is not iterable
# Traceback (most recent call last):
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\limbi\anaconda3\lib\site-packages\dtale\views.py", line 2867, in get_data
#     curr_dtypes = [c["name"] for c in global_state.get_dtypes(data_id)]
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ### Checking and Treating Missing Values

# %%
#Identify Missing Values

raw_data.isnull().sum()

# %%
#Locate the row of Missing Values
trace_missing_age = pd.isnull(raw_data['Age'])
raw_data[trace_missing_age]

# %%
trace_missing_hp = pd.isnull(raw_data['HP'])
raw_data[trace_missing_hp]

# %%
trace_missing_MetColor = pd.isnull(raw_data['MetColor'])
raw_data[trace_missing_MetColor]

# %%
#Treating Missing Values

#Replace with Mean
raw_data.Age = raw_data.Age.fillna(raw_data.Age.mean()) #By Column

# %%
#Most Frequent or mode for MetColor
raw_data.MetColor = raw_data.MetColor.fillna(raw_data.MetColor.mode()[0]) #By Column

# %%
#Delete Missing Value based on particular column
raw_data=raw_data.dropna(subset=['HP'])

# %%
#Recheck
raw_data.isnull().sum()

# %% [markdown]
# ## Checking Duplicated Rows

# %%
#Check duplicated rows
raw_data[raw_data.duplicated(keep=False)]

# %%
#Remove duplicates and keep the first
raw_data.drop_duplicates(keep='first', inplace = True) #Inplace true mean no need to assigned into new variable

#Recheck again
raw_data[raw_data.duplicated(keep=False)]

# %%
#Reset into new index
raw_data = raw_data.reset_index(drop=True)

# %%
#Copy cleaned data into new dataframe (optional)

data_clean = raw_data.copy()
data_clean.head()

# %%
raw_data

# %%
data_clean

# %% [markdown]
# ## Statistics Exploration

# %%
#Data Exploration

#Descriptive Statistics
data_clean.describe(include = 'all')

# %%
# Check total number of attributes
print("No. of Attributes (Columns): ",len(data_clean.columns))
print("No. of sample (Rows): ",len(data_clean))

# %% [markdown]
# ### Measure of Central Tendency

# %%
#Checking for Mean
#data.mean()
pd.DataFrame(round(data_clean.mean(),2),columns=['Mean'])

# %%
#Checking for Median
#data.median()
pd.DataFrame(round(data_clean.median(),2),columns=['Median'])

# %%
#Checking for Mode
data_clean.mode()

# %% [markdown]
# ### Exploring the Probability Distribution Function

# %%
#Call Description
data_clean.describe()

# %%
# Plotting Distribution Graph
sns.distplot(data_clean['Price'])

# %% [markdown]
# Outliers = observation that lie on abnormal distance from other observations in the data.
# It affect the regression. It will cause the coefficient to be inflated.
# To deal with this, remove top 1% of observation

# %%
#Removing Outliers using Quantile Method. Get the 99th percentile and keep the data below it
q = data_clean['Price'].quantile(0.99)
data_clean = data_clean[data_clean['Price']<q]
data_clean.describe(include='all')

# %%
# Plotting Distribution Graph
sns.distplot(data_clean['Price'])

# %%
# Feature Selection
# Correlation 
data_clean.corr()

# Heatmap Correlation
plt.figure(figsize=(8,8))
sns.heatmap(data_clean.corr(), annot=True, cmap='coolwarm')
#Annot is to add the annotation from correlation matrix
#cmap - color map

# %%
data_FeatureSelection = data_clean[['Age','KM', 'HP', 'Weight','Price']]
data_FeatureSelection

# %% [markdown]
# ### Plotting Distribution Graph
# sns.distplot(data_clean['HP'])

# %% [markdown]
# #Removing Outliers using Quantile Method. Get the 99th percentile and keep the data below it
# q = data_clean['HP'].quantile(0.99)
# data_clean = data_clean[data_clean['HP']<q]
# data_clean.describe(include='all')

# %% [markdown]
# ### Checking for Linearity Assumption between Price & Continuous Input Variables

# %%
#Plotting Pairplot of scattered data point (Not Necessary)
sns.pairplot(data_clean)

# %%
#Plotting Price vs Age, Price vs KM & Price vs HP
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(15,3))

ax1.scatter(data_clean['Age'],data_clean['Price'])
ax1.set_title('Price and Age')
ax2.scatter(data_clean['KM'],data_clean['Price'])
ax2.set_title('Price and KM')
ax3.scatter(data_clean['HP'],data_clean['Price'])
ax3.set_title('Price and HP')

plt.show()

# %%
# Apply Log Transformation to deal with exponential relationship
log_price = np.log(data_clean['Price'])
data_clean['Log_Price']=log_price #Add new transform data point into the dataframe

# %%
data_clean.head()

# %%
#Plotting Price vs Age, Price vs KM & Price vs HP
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(15,3))

ax1.scatter(data_clean['Age'],data_clean['Log_Price'])
ax1.set_title('Price and Age')
ax2.scatter(data_clean['KM'],data_clean['Log_Price'])
ax2.set_title('Price and KM')
ax3.scatter(data_clean['HP'],data_clean['Log_Price'])
ax3.set_title('Price and HP')

plt.show()

# %%
data_clean=data_clean.drop(['Log_Price'], axis=1)
data_clean.head()

# %% [markdown]
# ## Features Selection

# %% [markdown]
# ### Check for correlation
# #### Selection can be based on mathematical parameters and logical relationship.

# %% [markdown]
# ## Handling Dummy Data

# %%
#Create dummy variables for categorical variable
data_with_dummy = pd.get_dummies(data_clean)
data_with_dummy = pd.get_dummies(data_clean,drop_first=True)
data_with_dummy.head()

# %%
# Correlation 
data_with_dummy.corr()

# Heatmap Correlation
plt.figure(figsize=(8,8))
sns.heatmap(data_with_dummy.corr(), annot=True, cmap='coolwarm')
#Annot is to add the annotation from correlation matrix
#cmap - color map

# %%
data= data_clean[['KM', 'HP', 'Age', 'Weight','Price']]
data

# %% [markdown]
# Choose features with at least 0.2 correlation with Price.
