# %% [markdown]
# ## Data Preprocessing - Car Price

# %% [markdown]
# ## Import Packages

# %%
# Import Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\User\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\User\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\User\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Import Dataset

# %%
# Import Dataset
raw_data = pd.read_csv('car_price_raw.csv')
raw_data.head(11)
# Out:
#     Price   Age     KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0  46986   Diesel   90.0       1.0          0  2000      3
# 1   13750  23.0  72937   Diesel   90.0       1.0          0  2000      3
# 2   13950  24.0  41711   Diesel   90.0       1.0          0  2000      3
# 3   14950  26.0  48000   Diesel   90.0       0.0          0  2000      3
# 4   13750   NaN  38500   Diesel   90.0       0.0          0  2000      3
# 5   12950  32.0  61000   Diesel   90.0       0.0          0  2000      3
# 6   16900  27.0  94612   Diesel   90.0       1.0          0  2000      3
# 7   18600  30.0  75889   Diesel   90.0       1.0          0  2000      3
# 8   21500  27.0  19700   Petrol  192.0       0.0          0  1800      3
# 9   21500  27.0  19700   Petrol  192.0       0.0          0  1800      3
# 10  12950  23.0  71138   Diesel   69.0       0.0          0  1900      3
#
#     Weight
# 0     1165
# 1     1165
# 2     1165
# 3     1165
# 4     1170
# 5     1170
# 6     1245
# 7     1245
# 8     1185
# 9     1185
# 10    1105

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Overview about the dataset

# %%
# Check total number of attributes
print("No. of Attributes (Columns): ",len(raw_data.columns))
print("No. of sample (Rows): ",len(raw_data))
# Out:
# No. of Attributes (Columns):  10
# No. of sample (Rows):  1437

# %%
raw_data.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1437.000000  1436.000000    1437.000000  1436.000000  1436.000000
# mean   10738.318720    55.944986   68499.276966   101.502089     0.674095
# std     3636.814232    18.603073   37515.511159    14.981080     0.468875
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63328.000000   110.000000     1.000000
# 75%    11950.000000    70.000000   87000.000000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC        Doors       Weight
# count  1437.000000  1437.000000  1437.000000  1437.000000
# mean      0.055672  1566.990257     4.032707  1072.537926
# std       0.229366   187.218323     0.952735    52.706466
# min       0.000000  1300.000000     2.000000  1000.000000
# 25%       0.000000  1400.000000     3.000000  1040.000000
# 50%       0.000000  1600.000000     4.000000  1070.000000
# 75%       0.000000  1600.000000     5.000000  1085.000000
# max       1.000000  2000.000000     5.000000  1615.000000

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 1. YData Profiling (Previously Pandas Profiling)

# %% [markdown]
# ### Interactive and Comprehensive Descriptive Analysis using Pandas-Profiling

# %%
import ydata_profiling as pp
#Interactive and comprehensive EDA/ data description

# forming ProfileReport and save
# as output.html file
profile = pp.ProfileReport(raw_data)
profile.to_file("output_raw_data.html")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# C:\Users\User\anaconda3\lib\site-packages\visions\backends\shared\nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 2. D-Tale

# %% [markdown]
# D-Tale takes your Pandas dataframe to a whole new level. This powerful and fast library makes it very easy to interact with your data, carry out basic analysis and even edit it.

# %%
import dtale

dtale.show(raw_data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://MSI:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2023-10-18 09:24:03,810 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,824 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,825 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,827 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,830 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,835 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,838 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,845 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,847 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,849 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,877 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,879 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,881 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,883 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,885 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,887 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,889 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,891 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,893 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,897 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,901 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,904 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,908 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,910 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,914 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,917 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,920 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,923 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,959 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,967 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,971 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,975 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,992 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,994 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:03,996 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,005 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,010 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,013 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,022 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,025 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,028 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,030 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,032 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,034 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,037 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,040 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,042 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,045 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,047 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,050 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,052 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,058 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,062 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,065 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,068 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,070 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:04,074 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,648 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,652 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,653 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,654 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,655 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,657 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,658 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,659 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,661 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,662 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,664 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,671 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,674 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,713 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,714 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,716 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,717 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,719 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,720 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,722 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,724 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,725 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,729 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,738 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,739 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,741 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,742 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,743 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,745 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,746 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,748 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,749 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,750 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,752 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,754 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,793 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,795 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,798 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,800 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,803 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,806 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,808 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,810 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,812 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,813 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,815 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,857 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,859 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,861 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,863 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,865 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,867 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,868 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,870 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,873 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:10,874 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,014 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,018 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,020 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,021 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,023 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,025 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,027 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,029 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,031 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,033 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,034 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,053 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,054 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,056 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,058 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,061 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,064 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,067 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,069 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,071 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,073 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,090 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,095 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,097 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,099 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,101 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,103 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,104 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,106 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,109 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,110 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,112 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,113 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:12,116 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,942 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,945 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,947 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,948 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,949 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,951 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,954 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,960 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,962 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,965 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,986 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,988 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,990 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,992 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,993 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,994 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,995 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:15,997 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,000 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,002 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,004 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,008 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,010 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,012 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,014 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,016 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,019 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,021 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,042 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,043 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,044 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,046 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,054 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,056 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,058 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,063 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,064 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,066 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,074 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,075 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,076 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,077 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,079 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,082 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,082 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,083 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,084 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,086 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,087 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,089 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,090 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,093 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,096 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,098 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,100 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,102 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-18 09:24:16,105 - WARNING  - findfont: Font family 'Heiti TC' not found.
# C:\Users\User\anaconda3\lib\site-packages\dtale\views.py:2110: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# 2023-10-18 09:25:44,661 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\views.py", line 3102, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\column_analysis.py", line 186, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\column_analysis.py", line 162, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "<__array_function__ internals>", line 200, in histogram
#   File "C:\Users\User\anaconda3\lib\site-packages\numpy\lib\histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "C:\Users\User\anaconda3\lib\site-packages\numpy\lib\histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "C:\Users\User\anaconda3\lib\site-packages\numpy\lib\histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2023-10-18 09:26:07,949 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\views.py", line 3102, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\column_analysis.py", line 142, in build
#     return_data, code = self.analysis.build(self)
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\column_analysis.py", line 458, in build
#     hist = self.build_hist(s, code)
#   File "C:\Users\User\anaconda3\lib\site-packages\dtale\column_analysis.py", line 512, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "C:\Users\User\anaconda3\lib\site-packages\pandas\core\generic.py", line 5902, in __getattr__
#     return object.__getattribute__(self, name)
#   File "C:\Users\User\anaconda3\lib\site-packages\pandas\core\accessor.py", line 182, in __get__
#     accessor_obj = self._accessor(obj)
#   File "C:\Users\User\anaconda3\lib\site-packages\pandas\core\strings\accessor.py", line 181, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "C:\Users\User\anaconda3\lib\site-packages\pandas\core\strings\accessor.py", line 235, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# D-Tale comes with a large number of features that allow you to interrogate the data, visualise its completeness, edit the data and more.
#
# When we look into individual variables, such as the DTC column within this dataset, we can visualise the distribution of it using histograms:

# %% [markdown]
# ### 3. SweetViz

# %% [markdown]
# SweetViz is another low code, interactive data visualisation and exploration library. From a couple of lines of code, we are able to create an interactive HTML file to explore our data.

# %%
import sweetviz as sv

report = sv.analyze(raw_data)
report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 4. Missingno

# %% [markdown]
# If you are interested in using a lightweight library to explore the completeness of your data, then missingno is one you should definitely consider for your EDA toolbox.
#
# It is a Python library that provides a series of visualisations to understand the presence and distribution of missing data within a pandas dataframe. The library provides you with a small number of plots (barplot, matrix plot, heatmap or dendrogram) to visualise what columns in your dataframe contain missing values and how the degree of missingness is related between the variables.

# %%
import missingno as msno

msno.bar(raw_data)
msno.matrix(raw_data)
msno.dendrogram(raw_data)
msno.heatmap(raw_data)
# Out:
# <Axes: >

# %% [markdown]
# The above four plots provide us insight into:
#
# How complete each column within the dataframe is — msno.bar()
# Where the missing data occurs — msno.matrix()
# How correlated the missing values are — msno.heatmap() and msno.dendrogram()
# The nice thing about this library is that the plots are clean, easy to understand and can be quickly incorporated into a report as they are.

# %% [markdown]
# ### 5. Sketch

# %% [markdown]
# Sketch is a very new (as of Feb 2023) library that leverages the power of AI to help you understand your pandas dataframes by using natural language questions directly within Jupyter. You can also use it to generate sample code, for example how to make a plot of x and y within the dataframe, and then use that code to generate the required plot.
#
# The library is mostly self contained, where it uses machine learning algorithms to understand the context of your question in relation to your dataset. There is a function that does rely on OpenAI’s API, but that does not detract from how the library can be used.
#
# Sketch has a lot of potential to be powerful, especially if you are looking to provide an interface to customers with very limited knowledge of coding in Python.

# %%
import sketch

raw_data.sketch.ask('What are the max values of each numerical column?')
# Out:
# Price: 32500.0
# Age: 80.0
# KM: 243000.0
# HP: 192.0
# MetColor: 1.0
# Automatic: 1.0
# CC: 2000.0
# Doors: 5.0
# Weight: 1615.0

# %%
raw_data.sketch.howto("""How do I plot KM against Price 
                using a scatter plot and have the coloured in rainbow?""")
# Out:
# <div style="display:flex;flex-direction:row;justify-content:space-between;">
#                 <pre style="width: 100%; white-space: pre-wrap;" id="2a999c4b-c95d-4cfd-8faa-ab878a968f2c">
# import matplotlib.pyplot as plt
#
# # Create a scatter plot of KM vs Price
# plt.scatter(raw_data['KM'], raw_data['Price'], c=raw_data['KM'], cmap='rainbow')
#
# # Add labels and title
# plt.xlabel('Kilometers')
# plt.ylabel('Price')
# plt.title('Kilometers vs Price')
#
# # Show the plot
# plt.show()
# </pre>
#                 <button style="height: fit-content;" onclick="navigator.clipboard.writeText(JSON.parse(atob(``)))">Copy</button>
#                 </div>

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of KM vs Price
plt.scatter(raw_data['KM'], raw_data['Price'], c=raw_data['KM'], cmap='rainbow')

# Add labels and title
plt.xlabel('Kilometers')
plt.ylabel('Price')
plt.title('Kilometers vs Price')

# Show the plot
plt.show()

# %% [markdown]
# ### Checking and Treating Missing Values

# %%
#Identify Missing Values

raw_data.isnull().sum()
# Out:
# Price        0
# Age          1
# KM           0
# FuelType     0
# HP           1
# MetColor     1
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_age = pd.isnull(raw_data['Age'])
raw_data[trace_missing_age]
# Out:
#    Price  Age     KM FuelType    HP  MetColor  Automatic    CC  Doors  Weight
# 4  13750  NaN  38500   Diesel  90.0       0.0          0  2000      3    1170

# %%
trace_missing_hp = pd.isnull(raw_data['HP'])
raw_data[trace_missing_hp]
# Out:
#     Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 14  21500  31.0  23000   Petrol NaN       1.0          0  1800      3    1185

# %%
trace_missing_MetColor = pd.isnull(raw_data['MetColor'])
raw_data[trace_missing_MetColor]
# Out:
#     Price   Age     KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 18  17950  24.0  21716   Petrol  110.0       NaN          0  1600      3
#
#     Weight
# 18    1105

# %%
#Treating Missing Values

#Replace with Mean
raw_data.Age = raw_data.Age.fillna(raw_data.Age.mean()) #By Column

# %%
#Most Frequent or mode for MetColor
raw_data.MetColor = raw_data.MetColor.fillna(raw_data.MetColor.mode()[0]) #By Column

# %%
#Delete Missing Value based on particular column
raw_data=raw_data.dropna(subset=['HP'])

# %%
#Recheck
raw_data.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %% [markdown]
# ## Checking Duplicated Rows

# %%
#Check duplicated rows
raw_data[raw_data.duplicated(keep=False)]
# Out:
#      Price   Age     KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 8    21500  27.0  19700   Petrol  192.0       0.0          0  1800      3
# 9    21500  27.0  19700   Petrol  192.0       0.0          0  1800      3
# 113  24950   8.0  13253   Diesel  116.0       1.0          0  2000      5
# 114  24950   8.0  13253   Diesel  116.0       1.0          0  2000      5
#
#      Weight
# 8      1185
# 9      1185
# 113    1320
# 114    1320

# %%
#Remove duplicates and keep the first
raw_data.drop_duplicates(keep='first', inplace = True) #Inplace true mean no need to assigned into new variable

#Recheck again
raw_data[raw_data.duplicated(keep=False)]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9848\4019560435.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Empty DataFrame
# Columns: [Price, Age, KM, FuelType, HP, MetColor, Automatic, CC, Doors, Weight]
# Index: []

# %%
#Reset into new index
raw_data = raw_data.reset_index(drop=True)

# %%
#Copy cleaned data into new dataframe (optional)

data_clean = raw_data.copy()
data_clean.head()
# Out:
#    Price        Age     KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.000000  46986   Diesel  90.0       1.0          0  2000      3
# 1  13750  23.000000  72937   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.000000  41711   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.000000  48000   Diesel  90.0       0.0          0  2000      3
# 4  13750  55.944986  38500   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
raw_data
# Out:
#       Price        Age     KM FuelType     HP  MetColor  Automatic    CC  \
# 0     13500  23.000000  46986   Diesel   90.0       1.0          0  2000
# 1     13750  23.000000  72937   Diesel   90.0       1.0          0  2000
# 2     13950  24.000000  41711   Diesel   90.0       1.0          0  2000
# 3     14950  26.000000  48000   Diesel   90.0       0.0          0  2000
# 4     13750  55.944986  38500   Diesel   90.0       0.0          0  2000
# ...     ...        ...    ...      ...    ...       ...        ...   ...
# 1429   7500  69.000000  20544   Petrol   86.0       1.0          0  1300
# 1430  10845  72.000000  19000   Petrol   86.0       0.0          0  1300
# 1431   8500  71.000000  17016   Petrol   86.0       0.0          0  1300
# 1432   7250  70.000000  16916   Petrol   86.0       1.0          0  1300
# 1433   6950  76.000000      1   Petrol  110.0       0.0          0  1600
#
#       Doors  Weight
# 0         3    1165
# 1         3    1165
# 2         3    1165
# 3         3    1165
# 4         3    1170
# ...     ...     ...
# 1429      3    1025
# 1430      3    1015
# 1431      3    1015
# 1432      3    1015
# 1433      5    1114
#
# [1434 rows x 10 columns]

# %%
data_clean
# Out:
#       Price        Age     KM FuelType     HP  MetColor  Automatic    CC  \
# 0     13500  23.000000  46986   Diesel   90.0       1.0          0  2000
# 1     13750  23.000000  72937   Diesel   90.0       1.0          0  2000
# 2     13950  24.000000  41711   Diesel   90.0       1.0          0  2000
# 3     14950  26.000000  48000   Diesel   90.0       0.0          0  2000
# 4     13750  55.944986  38500   Diesel   90.0       0.0          0  2000
# ...     ...        ...    ...      ...    ...       ...        ...   ...
# 1429   7500  69.000000  20544   Petrol   86.0       1.0          0  1300
# 1430  10845  72.000000  19000   Petrol   86.0       0.0          0  1300
# 1431   8500  71.000000  17016   Petrol   86.0       0.0          0  1300
# 1432   7250  70.000000  16916   Petrol   86.0       1.0          0  1300
# 1433   6950  76.000000      1   Petrol  110.0       0.0          0  1600
#
#       Doors  Weight
# 0         3    1165
# 1         3    1165
# 2         3    1165
# 3         3    1165
# 4         3    1170
# ...     ...     ...
# 1429      3    1025
# 1430      3    1015
# 1431      3    1015
# 1432      3    1015
# 1433      5    1114
#
# [1434 rows x 10 columns]

# %% [markdown]
# ## Statistics Exploration

# %%
#Data Exploration

#Descriptive Statistics
data_clean.describe(include = 'all')
# Out:
#                Price          Age             KM FuelType           HP  \
# count    1434.000000  1434.000000    1434.000000     1434  1434.000000
# unique           NaN          NaN            NaN        3          NaN
# top              NaN          NaN            NaN   Petrol          NaN
# freq             NaN          NaN            NaN     1263          NaN
# mean    10713.398884    56.016001   68603.562064      NaN   101.428870
# std      3598.736494    18.545330   37484.833847      NaN    14.794551
# min      4350.000000     1.000000       1.000000      NaN    69.000000
# 25%      8450.000000    44.000000   43000.000000      NaN    90.000000
# 50%      9900.000000    61.000000   63455.000000      NaN   110.000000
# 75%     11950.000000    70.000000   87062.250000      NaN   110.000000
# max     32500.000000    80.000000  243000.000000      NaN   192.000000
#
#            MetColor    Automatic           CC        Doors       Weight
# count   1434.000000  1434.000000  1434.000000  1434.000000  1434.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.674338     0.055788  1566.363319     4.033473  1072.208508
# std        0.468785     0.229592   186.861091     0.952608    52.185178
# min        0.000000     0.000000  1300.000000     2.000000  1000.000000
# 25%        0.000000     0.000000  1400.000000     3.000000  1040.000000
# 50%        1.000000     0.000000  1600.000000     4.000000  1070.000000
# 75%        1.000000     0.000000  1600.000000     5.000000  1085.000000
# max        1.000000     1.000000  2000.000000     5.000000  1615.000000

# %%
# Check total number of attributes
print("No. of Attributes (Columns): ",len(data_clean.columns))
print("No. of sample (Rows): ",len(data_clean))
# Out:
# No. of Attributes (Columns):  10
# No. of sample (Rows):  1434

# %% [markdown]
# ### Measure of Central Tendency

# %%
#Checking for Mean
#data.mean()
pd.DataFrame(round(data_clean.mean(),2),columns=['Mean'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\906742122.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#                Mean
# Price      10713.40
# Age           56.02
# KM         68603.56
# HP           101.43
# MetColor       0.67
# Automatic      0.06
# CC          1566.36
# Doors          4.03
# Weight      1072.21

# %%
#Checking for Median
#data.median()
pd.DataFrame(round(data_clean.median(),2),columns=['Median'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\3316322618.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#             Median
# Price       9900.0
# Age           61.0
# KM         63455.0
# HP           110.0
# MetColor       1.0
# Automatic      0.0
# CC          1600.0
# Doors          4.0
# Weight      1070.0

# %%
#Checking for Mode
data_clean.mode()
# Out:
#    Price   Age     KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0   8950  68.0  36000   Petrol  110.0       1.0          0  1600      5
#
#    Weight
# 0    1075

# %% [markdown]
# ### Exploring the Probability Distribution Function

# %%
#Call Description
data_clean.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1434.000000  1434.000000    1434.000000  1434.000000  1434.000000
# mean   10713.398884    56.016001   68603.562064   101.428870     0.674338
# std     3598.736494    18.545330   37484.833847    14.794551     0.468785
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63455.000000   110.000000     1.000000
# 75%    11950.000000    70.000000   87062.250000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC        Doors       Weight
# count  1434.000000  1434.000000  1434.000000  1434.000000
# mean      0.055788  1566.363319     4.033473  1072.208508
# std       0.229592   186.861091     0.952608    52.185178
# min       0.000000  1300.000000     2.000000  1000.000000
# 25%       0.000000  1400.000000     3.000000  1040.000000
# 50%       0.000000  1600.000000     4.000000  1070.000000
# 75%       0.000000  1600.000000     5.000000  1085.000000
# max       1.000000  2000.000000     5.000000  1615.000000

# %%
# Plotting Distribution Graph
sns.distplot(data_clean['Price'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\4286830043.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# Outliers = observation that lie on abnormal distance from other observations in the data.
# It affect the regression. It will cause the coefficient to be inflated.
# To deal with this, remove top 1% of observation

# %%
#Removing Outliers using Quantile Method. Get the 99th percentile and keep the data below it
q = data_clean['Price'].quantile(0.99)
data_clean = data_clean[data_clean['Price']<q]
data_clean.describe(include='all')
# Out:
#                Price          Age             KM FuelType           HP  \
# count    1418.000000  1418.000000    1418.000000     1418  1418.000000
# unique           NaN          NaN            NaN        3          NaN
# top              NaN          NaN            NaN   Petrol          NaN
# freq             NaN          NaN            NaN     1257          NaN
# mean    10554.054302    56.497846   69160.181946      NaN   101.161495
# std      3269.717890    18.058686   37288.363823      NaN    14.232667
# min      4350.000000     1.000000       1.000000      NaN    69.000000
# 25%      8450.000000    44.000000   43624.500000      NaN    86.000000
# 50%      9895.000000    61.000000   63959.000000      NaN   110.000000
# 75%     11895.000000    70.000000   87643.750000      NaN   110.000000
# max     22000.000000    80.000000  243000.000000      NaN   192.000000
#
#            MetColor    Automatic           CC        Doors       Weight
# count   1418.000000  1418.000000  1418.000000  1418.000000  1418.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.672073     0.056417  1562.739774     4.026798  1069.930889
# std        0.469624     0.230808   183.992381     0.952278    46.207177
# min        0.000000     0.000000  1300.000000     2.000000  1000.000000
# 25%        0.000000     0.000000  1400.000000     3.000000  1040.000000
# 50%        1.000000     0.000000  1600.000000     4.000000  1065.000000
# 75%        1.000000     0.000000  1600.000000     5.000000  1085.000000
# max        1.000000     1.000000  2000.000000     5.000000  1615.000000

# %%
# Plotting Distribution Graph
sns.distplot(data_clean['Price'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\4286830043.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# Feature Selection
# Correlation 
data_clean.corr()

# Heatmap Correlation
plt.figure(figsize=(8,8))
sns.heatmap(data_clean.corr(), annot=True, cmap='coolwarm')
#Annot is to add the annotation from correlation matrix
#cmap - color map
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\582121186.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\582121186.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
data_FeatureSelection = data_clean[['Age','KM', 'HP', 'Weight','Price']]
data_FeatureSelection
# Out:
#             Age     KM     HP  Weight  Price
# 0     23.000000  46986   90.0    1165  13500
# 1     23.000000  72937   90.0    1165  13750
# 2     24.000000  41711   90.0    1165  13950
# 3     26.000000  48000   90.0    1165  14950
# 4     55.944986  38500   90.0    1170  13750
# ...         ...    ...    ...     ...    ...
# 1429  69.000000  20544   86.0    1025   7500
# 1430  72.000000  19000   86.0    1015  10845
# 1431  71.000000  17016   86.0    1015   8500
# 1432  70.000000  16916   86.0    1015   7250
# 1433  76.000000      1  110.0    1114   6950
#
# [1418 rows x 5 columns]

# %% [markdown]
# ### Plotting Distribution Graph
# sns.distplot(data_clean['HP'])

# %% [markdown]
# #Removing Outliers using Quantile Method. Get the 99th percentile and keep the data below it
# q = data_clean['HP'].quantile(0.99)
# data_clean = data_clean[data_clean['HP']<q]
# data_clean.describe(include='all')

# %% [markdown]
# ### Checking for Linearity Assumption between Price & Continuous Input Variables

# %%
#Plotting Pairplot of scattered data point (Not Necessary)
sns.pairplot(data_clean)

# %%
#Plotting Price vs Age, Price vs KM & Price vs HP
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(15,3))

ax1.scatter(data_clean['Age'],data_clean['Price'])
ax1.set_title('Price and Age')
ax2.scatter(data_clean['KM'],data_clean['Price'])
ax2.set_title('Price and KM')
ax3.scatter(data_clean['HP'],data_clean['Price'])
ax3.set_title('Price and HP')

plt.show()

# %%
# Apply Log Transformation to deal with exponential relationship
log_price = np.log(data_clean['Price'])
data_clean['Log_Price']=log_price #Add new transform data point into the dataframe
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17956\1517223109.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_clean.head()
# Out:
#    Price        Age     KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.000000  46986   Diesel  90.0       1.0          0  2000      3
# 1  13750  23.000000  72937   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.000000  41711   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.000000  48000   Diesel  90.0       0.0          0  2000      3
# 4  13750  55.944986  38500   Diesel  90.0       0.0          0  2000      3
#
#    Weight  Log_Price
# 0    1165   9.510445
# 1    1165   9.528794
# 2    1165   9.543235
# 3    1165   9.612467
# 4    1170   9.528794

# %%
#Plotting Price vs Age, Price vs KM & Price vs HP
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(15,3))

ax1.scatter(data_clean['Age'],data_clean['Log_Price'])
ax1.set_title('Price and Age')
ax2.scatter(data_clean['KM'],data_clean['Log_Price'])
ax2.set_title('Price and KM')
ax3.scatter(data_clean['HP'],data_clean['Log_Price'])
ax3.set_title('Price and HP')

plt.show()

# %%
data_clean=data_clean.drop(['Log_Price'], axis=1)
data_clean.head()
# Out:
#    Price        Age     KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.000000  46986   Diesel  90.0       1.0          0  2000      3
# 1  13750  23.000000  72937   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.000000  41711   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.000000  48000   Diesel  90.0       0.0          0  2000      3
# 4  13750  55.944986  38500   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %% [markdown]
# ## Features Selection

# %% [markdown]
# ### Check for correlation
# #### Selection can be based on mathematical parameters and logical relationship.

# %% [markdown]
# ## Handling Dummy Data

# %%
#Create dummy variables for categorical variable
data_with_dummy = pd.get_dummies(data_clean)
data_with_dummy = pd.get_dummies(data_clean,drop_first=True)
data_with_dummy.head()
# Out:
#    Price        Age     KM    HP  MetColor  Automatic    CC  Doors  Weight  \
# 0  13500  23.000000  46986  90.0       1.0          0  2000      3    1165
# 1  13750  23.000000  72937  90.0       1.0          0  2000      3    1165
# 2  13950  24.000000  41711  90.0       1.0          0  2000      3    1165
# 3  14950  26.000000  48000  90.0       0.0          0  2000      3    1165
# 4  13750  55.944986  38500  90.0       0.0          0  2000      3    1170
#
#    FuelType_Diesel  FuelType_Petrol
# 0                1                0
# 1                1                0
# 2                1                0
# 3                1                0
# 4                1                0

# %%
# Correlation 
data_with_dummy.corr()

# Heatmap Correlation
plt.figure(figsize=(8,8))
sns.heatmap(data_with_dummy.corr(), annot=True, cmap='coolwarm')
#Annot is to add the annotation from correlation matrix
#cmap - color map
# Out:
# <Axes: >

# %%
data= data_clean[['KM', 'HP', 'Age', 'Weight','Price']]
data
# Out:
#          KM     HP        Age  Weight  Price
# 0     46986   90.0  23.000000    1165  13500
# 1     72937   90.0  23.000000    1165  13750
# 2     41711   90.0  24.000000    1165  13950
# 3     48000   90.0  26.000000    1165  14950
# 4     38500   90.0  55.944986    1170  13750
# ...     ...    ...        ...     ...    ...
# 1429  20544   86.0  69.000000    1025   7500
# 1430  19000   86.0  72.000000    1015  10845
# 1431  17016   86.0  71.000000    1015   8500
# 1432  16916   86.0  70.000000    1015   7250
# 1433      1  110.0  76.000000    1114   6950
#
# [1418 rows x 5 columns]

# %% [markdown]
# Choose features with at least 0.2 correlation with Price.
